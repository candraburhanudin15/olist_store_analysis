# %% [markdown]
# # Proyek Analisis Data: Nama dataset
# - Nama: Candra Burhanudin
# - Email: candra065118309@unpak.ac.id
# - Username : candraburhanudin15

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana performa penjualan dan transaction E-Commerce dalam beberapa bulan terakhir?
# - kategori Produk apa yang paling banyak dan paling sedikit terjual?
# - Bagaimana sebaran pelanggan tertinggi yang kita miliki berdasarkan negara & kota?
# - Bagaimana Metode Pembayaran Pelanggan Yang sering digunakan?
# - berapa tingkat transaksi & jumlah order pelanggan yang di batalkan berdasarkan bulan terakhir?
# - Kapan terakhir pelanggan melakukan transaksi?
# - Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# - Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# - memuat tabel customer

# %%
customers_df = pd.read_csv('./data/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# - memuat tabel geolocation

# %%
geolocation_df = pd.read_csv('./data/geolocation_dataset.csv')
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# - memuat tabel order items

# %%
order_item_df = pd.read_csv('./data/order_items_dataset.csv')
order_item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# - memuat tabel order payments

# %%
order_payments_df = pd.read_csv('./data/order_payments_dataset.csv')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# - memuat tabel order reviews

# %%
order_reviews_df = pd.read_csv('./data/order_reviews_dataset.csv')
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# - memuat tabel orders

# %%
orders_df = pd.read_csv('./data/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# - memuat tabel category name translation

# %%
product_category_df = pd.read_csv('./data/product_category_name_translation.csv')
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# - memuat tabel product

# %%
products_df = pd.read_csv('./data/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# - memuat tabel sellers

# %%
sellers_df = pd.read_csv('./data/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ##### Assessing Customers_df

# %% [markdown]
# - rincian data customers

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# terlihat sudah tepat dalam segi jumlah data yg seimbang dan tipe data yang digunakan

# %% [markdown]
# - cek missing values

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# data customers_df tidak terdapat missing values

# %% [markdown]
# - cek duplikasi data

# %%
print('jumlah total duplikasi data :',customers_df.duplicated().sum())
# Out:
# jumlah total duplikasi data : 0

# %% [markdown]
# tidak terdapat duplikasi data

# %% [markdown]
# - cek ringkasan statistika

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# hasil data pada customer zip code terlihat baik baik saja

# %% [markdown]
# ##### Assessing geolocation_df

# %% [markdown]
# - rincian data geolocation

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# terlihat sudah tepat dalam segi jumlah data yg seimbang dan tipe data yang digunakan

# %% [markdown]
# - cek duplikasi data

# %%
print('jumlah duplikasi data :', geolocation_df.duplicated().sum())
# Out:
# jumlah duplikasi data : 261831

# %% [markdown]
# - cek missing values

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %% [markdown]
# geolocation_df tidak memiliki missing values

# %% [markdown]
# - cek hasil ringkasan statistika

# %%
geolocation_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# ##### Assessing order_items_df

# %% [markdown]
# - rincian data order item

# %%
order_item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# pada kolom shipping_limit_date memiliki tipe data object, seharusnya diubah menjadi tipe data datetime untuk mempermudah proses analisis data. Tipe data datetime memungkinkan Anda melakukan operasi waktu dan analisis deret waktu dengan lebih efisien.

# %% [markdown]
# - cek duplikasi data

# %%
print('jumlah duplikasi data :',order_item_df.duplicated().sum())
# Out:
# jumlah duplikasi data : 0

# %% [markdown]
# - cek missing values

# %%
order_item_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# tidak terdapat missing values

# %% [markdown]
# - cek ringkasan statistika

# %%
order_item_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ##### Assessing order_payments_df

# %% [markdown]
# - rincian data order items

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# jumlah data seimbang dan tidak ada tipe data yang perlu dirubah

# %% [markdown]
# - cek duplikasi data

# %%
print('jumlah total data duplikasi :',order_payments_df.duplicated().sum())
# Out:
# jumlah total data duplikasi : 0

# %% [markdown]
# - cek missing values

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# hasil tidak terdapat missing values

# %% [markdown]
# - cek ringkasan statistika

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# - cek invalid values

# %%
order_payments_df['payment_type'].value_counts()
# Out:
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: payment_type, dtype: int64

# %%
order_payments_df[order_payments_df['payment_value']== 0]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 19922   8bcbe01d44d147f901cd3192671144db                   4      voucher
# 36822   fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 43744   6ccb433e00daae1283ccc956189c82ae                   4      voucher
# 51280   4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57411   00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 62674   45ed6e85398a87c253db47c2d9f48216                   3      voucher
# 77885   fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 94427   c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 100766  b23878b3e8eb4d25a158f57d96331b18                   4      voucher
#
#         payment_installments  payment_value
# 19922                      1            0.0
# 36822                      1            0.0
# 43744                      1            0.0
# 51280                      1            0.0
# ...

# %% [markdown]
# dari pengamatan nilai payment_type = not_defined serupa dengan payment_type = voucher dimana pengguna tidak melakukan pembayaran karena menggunakan voucher. untuk itu nilai not_defined perlu di konversikan ke voucher

# %% [markdown]
# ##### Assessing order_reviews_df

# %% [markdown]
# - rincian data order reviews

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# pada kolom review_creation_date & review_answer_creation_date memiliki tipe data object, seharusnya mengonversikan menjadi tipe data datetime untuk mempermudah proses analisis data. Tipe data datetime memungkinkan Anda melakukan operasi waktu dan analisis deret waktu dengan lebih efisien.
#
# terlihat pada kolom review_comment_title dan review_comment_meesage memiliki jumlah yang tidak sama dengan yang lainnya

# %% [markdown]
# - cek duplikasi data

# %%
print('Jumlah total duplikasi data :',order_reviews_df.duplicated().sum())
# Out:
# Jumlah total duplikasi data : 0

# %% [markdown]
# - cek missing values

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# terdapat missing values pada review_comment_title sebanyak 87656 dan review_comment_message sebanyak 58247

# %% [markdown]
# - cek ringkasan statistika

# %%
order_reviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# ##### Assessing orders_df

# %% [markdown]
# - rincian data orders

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# pada kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date,	order_delivered_customer_date, order_estimated_delivery_date memiliki tipe data object, seharusnya mengonversikan menjadi tipe data datetime untuk mempermudah proses analisis data.
#
# terlihat order_approved_at, order_delivered_carrier_date, order_delivered_customer_date memiliki jumlah data yang tidak seimbang

# %% [markdown]
# - cek duplikasi data

# %%
orders_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - cek missing values

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# terdapat missing values pada order_approved_at, order_delivered_carrier_date, order_delivered_customer_date

# %% [markdown]
# - cek order status

# %%
orders_df.order_status.value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %% [markdown]
# ##### Assessing product_category_name_df

# %% [markdown]
# - rincian data product category

# %%
product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# - cek duplikasi data

# %%
print('Jumlah total duplikasi data :',product_category_df.duplicated().sum())
# Out:
# Jumlah total duplikasi data : 0

# %% [markdown]
# - cek missing values

# %%
product_category_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# tidak terdapat missing values

# %% [markdown]
# ##### Assessing product_df

# %% [markdown]
# - rincian data product

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# terdapat perbedaan jumlah data untuk itu perlu melakukan pengecekkan missing values, lalu perlu perubahan tipe data pada kolom product_photos_qty menjadi integer

# %% [markdown]
# - cek duplikasi data

# %%
print('Jumlah total duplikasi data :',products_df.duplicated().sum())
# Out:
# Jumlah total duplikasi data : 0

# %% [markdown]
# - cek missing values

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# dari angka diatas merujuk pada jumlah nilai missing values, perlu dilakukan penanganan pada proses selanjunya

# %% [markdown]
# - cek rincian statistika

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# ##### Assessing sellers_df

# %% [markdown]
# - rincian data seller

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# - cek duplikasi data

# %%
print('Total jumlah duplikasi data :',sellers_df.duplicated().sum())
# Out:
# Total jumlah duplikasi data : 0

# %% [markdown]
# - cek missing values

# %%
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# tidak terdapat missing values

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ##### Data cleaning customers_df

# %% [markdown]
# - Data Customer_df sudah baik

# %% [markdown]
# ##### Data cleaning geolocation_df

# %% [markdown]
# - membersihkan data duplikat

# %%
geolocation_df.drop_duplicates(inplace=True)
print('Jumlah total duplikasi data setelah dihapus : ',geolocation_df.duplicated().sum())
# Out:
# Jumlah total duplikasi data setelah dihapus :  0

# %% [markdown]
# ##### Data cleaning order_items_df

# %% [markdown]
# - memperbaiki kesalahan tipe data

# %%
order_item_df['shipping_limit_date'] = pd.to_datetime(order_item_df['shipping_limit_date'])

# %%
shipping_limit_date_check = order_item_df['shipping_limit_date'].dtype
print('tipe data kolom shipping limit date :', shipping_limit_date_check)
# Out:
# tipe data kolom shipping limit date : datetime64[ns]

# %%
order_item_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ##### Data cleaning order_payments_df

# %% [markdown]
# - mengatasi inaccurate data payment_type = not_defined dengan mengkonversikan menjadi voucher

# %%
order_payments_df[order_payments_df['payment_type']== 'not_defined']
# Out:
#                                order_id  payment_sequential payment_type  \
# 51280  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57411  00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 94427  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
#
#        payment_installments  payment_value
# 51280                     1            0.0
# 57411                     1            0.0
# 94427                     1            0.0

# %%
order_payments_df[order_payments_df['payment_value']== 0]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 19922   8bcbe01d44d147f901cd3192671144db                   4      voucher
# 36822   fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 43744   6ccb433e00daae1283ccc956189c82ae                   4      voucher
# 51280   4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57411   00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 62674   45ed6e85398a87c253db47c2d9f48216                   3      voucher
# 77885   fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 94427   c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 100766  b23878b3e8eb4d25a158f57d96331b18                   4      voucher
#
#         payment_installments  payment_value
# 19922                      1            0.0
# 36822                      1            0.0
# 43744                      1            0.0
# 51280                      1            0.0
# ...

# %%
order_payments_df.payment_type.replace('not_defined','voucher',inplace=True)

# %%
order_payments_df['payment_type'].value_counts()
# Out:
# credit_card    76795
# boleto         19784
# voucher         5778
# debit_card      1529
# Name: payment_type, dtype: int64

# %% [markdown]
# ##### Data cleaning order_reviews_df

# %% [markdown]
# - mengkonversi tipe data

# %%
datetimes_columns  =['review_creation_date', 'review_answer_timestamp']
for column in datetimes_columns:
    order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# - mengatasi nilai missing values dengan metode imputasi. karena kita tidak ingin menghapus data Nan diakrenakan hanya tidak mengisi judul dan deskripsi, maka data NaN akan diisi nilai default

# %%
order_reviews_df['review_comment_title'].fillna('no title',inplace=True)
order_reviews_df['review_comment_message'].fillna('no description', inplace=True)

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# ##### Data cleaning orders_df

# %% [markdown]
# - mengkonversi tipe data

# %%
datetimes_orders_df = ['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date','order_estimated_delivery_date']
for column in datetimes_orders_df:
    orders_df[column]= pd.to_datetime(orders_df[column])

# %% [markdown]
# - drop data invalid values

# %% [markdown]
# karena terdapat kekeliruan data dimana tanggal order approved_at barang lebih lama daripada tanggal order_delivered_carrier_date lebih dahulu. data perlu dihapus

# %%
data_shipped_abnormal = orders_df[(orders_df['order_status']== 'shipped') & \
                                  (orders_df['order_delivered_carrier_date'].notna()) & \
                                  (orders_df['order_approved_at'] > orders_df['order_delivered_carrier_date'])]
orders_df = orders_df.drop(data_shipped_abnormal.index)

# %%
data_delivery_abnormal = orders_df[(orders_df['order_status']== 'delivered') & \
                                    (orders_df['order_delivered_carrier_date'].notna()) & \
                                    (orders_df['order_approved_at'] > orders_df['order_delivered_carrier_date'])]
orders_df = orders_df.drop(data_delivery_abnormal.index)

# %% [markdown]
# karena terdapat kekeliruan data dimana tanggal order_delivered_carrier_date barang lebih lama daripada tanggal order_delivered_customer_date lebih dahulu yang seharusnya kebalikannya. data perlu dihapus

# %%
data_delivered_abnormal = orders_df[(orders_df['order_status']== 'delivered') & \
                                    (orders_df['order_delivered_customer_date'].notna()) & \
                                    (orders_df['order_delivered_carrier_date'] > orders_df['order_delivered_customer_date'])]
orders_df = orders_df.drop(data_delivered_abnormal.index)

# %% [markdown]
# - penanganan missing values pada order_status = unavailable dengan mengisi data tanggal terakhir (order_approved_at)

# %%
orders_df[(orders_df['order_status'] == 'unavailable') & orders_df['order_approved_at'].notna()]
# Out:
#                                order_id                       customer_id  \
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 586    c272bcd21c287498b4883c7512019702  9582c5bbecc65eb568e2c1d839b5cba1
# 687    37553832a3a89c9b2db59701c357ca67  7607cd563696c27ede287e515812d528
# 737    d57e15fb07fd180f06ab3926b39edcd2  470b93b3f1cde85550fc74cd3a476c78
# 1160   2f634e2cebf8c0283e7ef0989f77d217  7353b0fb8e8d9675e3a704c60ca44ebe
# ...                                 ...                               ...
# 99147  6cf5c427fb11bc5fe8abefa86aa7ba0b  91ac14a1e50bc022eeecf0c2ba37006a
# 99233  1c7c8ab324927f5b6e52338bd110bef4  95b1767df51d6fa09402267d8de314df
# 99252  aaab15da689073f8f9aa978a390a69d1  df20748206e4b865b2f14a5eabbfcf34
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
datetimes_orders_df_unavailable = ['order_delivered_carrier_date','order_delivered_customer_date']
for column in datetimes_orders_df_unavailable:
    mask = orders_df['order_status'] == 'unavailable'
    orders_df.loc[mask, column] = orders_df.loc[mask, column].fillna(orders_df.loc[mask, 'order_approved_at'])

# %% [markdown]
# - penanganan missing values pada order_status = processing dengan mengisi data tanggal terakhir (order_approved_at)

# %%
orders_df[(orders_df['order_status'] == 'processing') & orders_df['order_approved_at'].notna()]
# Out:
#                                order_id                       customer_id  \
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# 741    6a6c7d523fd59eb5bbefc007331af717  d954782ec6c0e911292c8a80757ef28d
# 1192   745e1d4a7f8c4b548881788d4113bb1d  7198d7088442e4ddfe553353d8ddc957
# 1516   1d52ba7197c7acebbb4f826f6585536f  c9c7fe860d602373a9e93f8bfe9d877a
# ...                                 ...                               ...
# 97400  dcdfc540e42725663242bb884c28f0a6  38972104038aa68fcc61277dbf6e7ca9
# 97666  e471815e7114cdb474064f7dbb1a8b67  092c9316ae71b2fe43e526043f351967
# 98089  10951d02d64917a34959abeb8130601e  3e6754e591ff3568ccc5bf69a649918c
# 99140  aea0db338150b526dde24f6fd953a5ed  379a02efdc6a56bd27f99b95fc2f6c06
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
datetimes_orders_df_processing = ['order_delivered_carrier_date','order_delivered_customer_date']
for column in datetimes_orders_df_processing:
    mask = orders_df['order_status'] == 'processing'
    orders_df.loc[mask, column] = orders_df.loc[mask, column].fillna(orders_df.loc[mask, 'order_approved_at'])

# %% [markdown]
# - penanganan missing values pada order_status = invoiced dengan mengisi data tanggal terakhir (order_approved_at)

# %%
orders_df[(orders_df['order_status'] == 'invoiced') & orders_df['order_approved_at'].notna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 455    38b7efdf33dd5561f4f5d4f6e07b0414  021e84751ba0ead75b6d314a6ead88d9
# 1833   51b0dccc8596ce37a930dff2d63a10a2  31bf1057b00f14804278590bbac18b1b
# 2116   5504eaa5a86eb25fa666cf2e6b96c701  a30be38e1ed0ffb39b318bf1d15e98d9
# ...                                 ...                               ...
# 98414  41ad2ae32ee66c07ef3b0301ba02ad27  5c7f8d14a0a12198d1d07167d7d343b3
# 98624  9ffb325177b96c422447e3b9ee9a6270  e4079117ea0dc8bc27274e34c4796515
# 98845  021dac6e3120485db6a77474aa21b979  c40f7f00e91eb8a0da1e58484380a796
# 99031  c526fe83c01c48066394ff5d81f9ab9a  6c678c38f3a0874b7bfeeb2d5fb22876
# 99066  46bdec7cc92d926500bee756ee1df6dc  0cfcefc0ed0af6a2e601540feeac24e7
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
datetimes_orders_df_invoiced = ['order_delivered_carrier_date','order_delivered_customer_date']
for column in datetimes_orders_df_invoiced:
    mask = orders_df['order_status'] == 'invoiced'
    orders_df.loc[mask, column] = orders_df.loc[mask, column].fillna(orders_df.loc[mask, 'order_approved_at'])

# %% [markdown]
# - penanganan missing values pada order_status = created dengan mengisi data tanggal terakhir (order_purchase_timestamp)

# %%
datetimes_orders_df_created = ['order_approved_at','order_delivered_carrier_date','order_delivered_customer_date']
for column in datetimes_orders_df_created:
    mask = orders_df['order_status'] == 'created'
    orders_df.loc[mask, column] = orders_df.loc[mask, column].fillna(orders_df.loc[mask, 'order_purchase_timestamp'])

# %% [markdown]
# - penanganan missing values pada order_status = approved dengan mengisi data tanggal terakhir (order_approved_at)

# %%
datetimes_orders_df_approved= ['order_delivered_carrier_date','order_delivered_customer_date']
for column in datetimes_orders_df_approved:
    mask = orders_df['order_status'] == 'approved'
    orders_df.loc[mask, column] = orders_df.loc[mask, column].fillna(orders_df.loc[mask, 'order_approved_at'])

# %% [markdown]
# - penanganan missing values pada order_status = shipped dengan mengisi data tanggal terakhir (order_delivered_carrier_date)

# %%
datetimes_orders_df_shipped= ['order_delivered_customer_date']
for column in datetimes_orders_df_shipped:
    mask = orders_df['order_status'] == 'shipped'
    orders_df.loc[mask, column] = orders_df.loc[mask, column].fillna(orders_df.loc[mask, 'order_delivered_carrier_date'])

# %% [markdown]
# - penanganan missing values pada order_status = canceled. dengan mengisi data tanggal terakhir (order_purchase_timestamp). kondisi ini mengelompokkan order dengan tingkat cancel paling awal (bisa terjadi karena cancel saat proses pembelian setelah pembayaran)

# %%
datetimes_orders_df_early_cancellation = ['order_approved_at','order_delivered_carrier_date', 'order_delivered_customer_date']

for column in datetimes_orders_df_early_cancellation:
    mask = (orders_df['order_status'] == 'canceled') & \
           orders_df['order_approved_at'].isna() & \
           orders_df['order_delivered_carrier_date'].isna() & \
           orders_df['order_delivered_customer_date'].isna()

    orders_df.loc[mask, column] = orders_df.loc[mask, column] = orders_df.loc[mask, 'order_purchase_timestamp']

# %% [markdown]
# - penanganan missing values pada order_status = canceled. dengan mengisi data tanggal terakhir (order_approved_at). kondisi ini mengelompokkan order dengan tingkat cancel menengah (bisa terjadi proses order sudah di setujui oleh penjual namun pembeli melakukan cancel order)

# %%
datetimes_orders_df_mid_cancellation = ['order_delivered_carrier_date', 'order_delivered_customer_date']
for column in datetimes_orders_df_mid_cancellation:
    mask = (orders_df['order_status'] == 'canceled') & \
            orders_df['order_delivered_carrier_date'].isna() & \
            orders_df['order_delivered_customer_date'].isna()
    
                        
    orders_df.loc[mask, column] = orders_df.loc[mask, column] = orders_df.loc[mask, 'order_approved_at']

# %% [markdown]
# - penanganan missing values pada order_status = canceled. dengan mengisi data tanggal terakhir (order_delivered_carrier_date). kondisi ini mengelompokkan order dengan tingkat cancel terakhir (bisa terjadi proses order barang sedang pengiriman namun pembeli melakukan proses cancel)

# %%
datetimes_orders_df_late_cancellation = ['order_delivered_customer_date']
for column in datetimes_orders_df_mid_cancellation:
    mask = (orders_df['order_status'] == 'canceled') & \
            orders_df['order_delivered_customer_date'].isna()
    orders_df.loc[mask, column] = orders_df.loc[mask, column] = orders_df.loc[mask, 'order_delivered_carrier_date']

# %% [markdown]
# - mengisi beberapa kolom missing values (order_approved_at) dengan metode Imputation pada order yang berhasil (order_status = delivered) dengan menggunakan nilai rata rata pada setiap kolomnya

# %%
filtered_delivered_approved_notna = orders_df[(orders_df['order_status']=='delivered') & orders_df['order_approved_at'].notna()].copy()
filtered_delivered_approved_notna['time_approval'] = filtered_delivered_approved_notna['order_approved_at'] - filtered_delivered_approved_notna['order_purchase_timestamp']
mean_time_approval = filtered_delivered_approved_notna['time_approval'].mean()
orders_df.loc[orders_df['order_status'] == 'delivered', 'order_approved_at'] = orders_df.loc[orders_df['order_status'] == 'delivered', 'order_approved_at'].fillna(orders_df['order_purchase_timestamp'] + mean_time_approval)

# %%
orders_df[(orders_df['order_status']=='delivered') & orders_df['order_approved_at'].isna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       0 non-null      object
#  1   customer_id                    0 non-null      object
#  2   order_status                   0 non-null      object
#  3   order_purchase_timestamp       0 non-null      datetime64[ns]
#  4   order_approved_at              0 non-null      datetime64[ns]
#  5   order_delivered_carrier_date   0 non-null      datetime64[ns]
#  6   order_delivered_customer_date  0 non-null      datetime64[ns]
#  7   order_estimated_delivery_date  0 non-null      datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 0.0+ bytes

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     2
# order_delivered_customer_date    8
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# - mengisi beberapa kolom missing values (order_delivered_carrier_date) dengan metode Imputation pada order yang berhasil (order_status = delivered) dengan menggunakan nilai rata rata pada setiap kolomnya

# %%
filtered_delivered_carrier_notna = orders_df[(orders_df['order_status']=='delivered') & orders_df['order_delivered_carrier_date'].notna()].copy()
filtered_delivered_carrier_notna['time_goods_start_shipping'] = filtered_delivered_carrier_notna['order_delivered_carrier_date'] - filtered_delivered_carrier_notna['order_approved_at']
mean_time_goods_start_shipping = filtered_delivered_carrier_notna['time_goods_start_shipping'].mean()
orders_df.loc[orders_df['order_status'] == 'delivered', 'order_delivered_carrier_date'] = orders_df.loc[orders_df['order_status'] == 'delivered', 'order_delivered_carrier_date'].fillna(orders_df['order_approved_at'] + mean_time_goods_start_shipping)

# %%
orders_df[(orders_df['order_status']=='delivered') & orders_df['order_delivered_carrier_date'].isna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       0 non-null      object
#  1   customer_id                    0 non-null      object
#  2   order_status                   0 non-null      object
#  3   order_purchase_timestamp       0 non-null      datetime64[ns]
#  4   order_approved_at              0 non-null      datetime64[ns]
#  5   order_delivered_carrier_date   0 non-null      datetime64[ns]
#  6   order_delivered_customer_date  0 non-null      datetime64[ns]
#  7   order_estimated_delivery_date  0 non-null      datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 0.0+ bytes

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    8
# order_estimated_delivery_date    0
# dtype: int64

# %%
filtered_delivered_customer_notna = orders_df[(orders_df['order_status']== 'delivered') & orders_df['order_delivered_customer_date'].notna()].copy()
filtered_delivered_customer_notna['shipping_time']= filtered_delivered_customer_notna['order_delivered_customer_date'] - filtered_delivered_customer_notna['order_delivered_carrier_date']
mean_shipping_time = filtered_delivered_customer_notna['shipping_time'].mean()
orders_df.loc[orders_df['order_status'] == 'delivered', 'order_delivered_customer_date'] = orders_df.loc[orders_df['order_status'] == 'delivered', 'order_delivered_customer_date'].fillna(orders_df['order_delivered_carrier_date'] + mean_shipping_time)

# %%
orders_df[(orders_df['order_status']== 'delivered') & orders_df['order_delivered_customer_date'].notna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95105 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       95105 non-null  object
#  1   customer_id                    95105 non-null  object
#  2   order_status                   95105 non-null  object
#  3   order_purchase_timestamp       95105 non-null  datetime64[ns]
#  4   order_approved_at              95105 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   95105 non-null  datetime64[ns]
#  6   order_delivered_customer_date  95105 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  95105 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.5+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# ##### Data cleaning product_df

# %% [markdown]
# - penanganan missing values menghapus data dengan dropna()

# %%
products_df[products_df.isna().any(axis=1)]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df = products_df.dropna(subset=['product_id','product_category_name','product_name_lenght','product_description_lenght','product_photos_qty','product_weight_g','product_length_cm','product_height_cm','product_width_cm'])

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# - konversi tipe data pada kolom product_photos_qty

# %%
products_df['product_photos_qty'] = products_df['product_photos_qty'].astype('Int64')

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32340 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32340 non-null  object
#  1   product_category_name       32340 non-null  object
#  2   product_name_lenght         32340 non-null  float64
#  3   product_description_lenght  32340 non-null  float64
#  4   product_photos_qty          32340 non-null  Int64
#  5   product_weight_g            32340 non-null  float64
#  6   product_length_cm           32340 non-null  float64
#  7   product_height_cm           32340 non-null  float64
#  8   product_width_cm            32340 non-null  float64
# dtypes: Int64(1), float64(6), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# **Proses ini memiliki tujuan antara lain**
#
# - membuat pertanyaan analisis atau bisnis
# - melakukan eksplorasi terhadap setiap data untuk mencari insight menarik guna menjawab pertanyaan bisnis tersebut.
#
# *Dataset publik e-commerce Brasil ini berasal dari pesanan yang dibuat di Olist Store. Dataset ini memiliki informasi dari 100 ribu pesanan dari tahun 2016 hingga 2018 yang dibuat di beberapa pasar di Brasil.*

# %% [markdown]
# #### Eksplorasi Data customers_df

# %% [markdown]
# - ringkasan statistika data customers_df

# %%
customers_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# terdapat 99441 jumlah pelanggan pada Olist Store yang tersebar di seluruh dunia

# %% [markdown]
# - pivot tabel demografi sebaran pelanggan di berbagai negara bagian

# %%
customer_demographics = customers_df.groupby(by='customer_state').agg({
      'customer_id': 'nunique',
      'customer_city': 'nunique',
})
customer_demographics = customer_demographics.sort_values(by='customer_id', ascending=False)
customer_demographics
# Out:
#                 customer_id  customer_city
# customer_state
# SP                    41746            629
# RJ                    12852            149
# MG                    11635            745
# RS                     5466            379
# PR                     5045            364
# SC                     3637            240
# BA                     3380            353
# DF                     2140              6
# ES                     2033             95
# GO                     2020            178
# PE                     1652            152
# CE                     1336            161
# PA                      975             89
# MT                      907            101
# MA                      747            122
# MS                      715             67
# PB                      536             92
# PI                      495             72
# RN                      485             90
# AL                      413             68
# ...

# %% [markdown]
# berdasarkan hasil tabel output diatas jumlah customer terbanyak berada pada negara inisial SP dengan 41746 yang tersebar di 629 penjuru kota

# %% [markdown]
# - pivot tabel demografi sebaran pelanggan di berbagai kota dunia

# %%
customers_df.groupby(by='customer_city').customer_id.nunique().sort_values(ascending=False).head(20)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# niteroi                    849
# santo andre                797
# osasco                     746
# santos                     713
# goiania                    692
# sao jose dos campos        691
# fortaleza                  654
# sorocaba                   633
# recife                     613
# florianopolis              570
# Name: customer_id, dtype: int64

# %% [markdown]
# kota dengan user pengguna terbanyak berada pada sao paulo dengan 15540 user

# %%
customers_df.groupby(by='customer_state').customer_id.nunique().sort_values(ascending=False).head(5)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# Name: customer_id, dtype: int64

# %% [markdown]
# #### Eksplorasi Data geolocation_df

# %% [markdown]
# - melihat jumlah persebaran 5 kota terbesar pada tiap wilayah negara

# %%
geolocation_df.groupby(by=['geolocation_state']).geolocation_city.nunique().sort_values(ascending=False).head(5)
# Out:
# geolocation_state
# MG    1426
# SP    1048
# RS     691
# BA     652
# PR     651
# Name: geolocation_city, dtype: int64

# %% [markdown]
# #### Eksplorasi Data order_items

# %% [markdown]
# - meninjau seller dengan transaksi penjualan tertinggi

# %%
best_seller_total_transactions = order_item_df.groupby(by='seller_id').agg({
        'price':'sum',
        'freight_value':'mean',
})
best_seller_transactions = best_seller_total_transactions.rename(columns={
    'price': 'total_price_item_transactions',
    'freight_value': 'average_shipping_costs',
})
best_seller_transactions.sort_values(by='total_price_item_transactions',ascending=False).head()
# Out:
#                                   total_price_item_transactions  \
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2                      229472.63
# 53243585a1d6dc2643021fd1853d8905                      222776.05
# 4a3ca9315b744ce9f8e9374361493884                      200472.92
# fa1c13f2614d7b5c4749cbc52fecda94                      194042.03
# 7c67e1448b00f6e969d365cea6b010ab                      187923.89
#
#                                   average_shipping_costs
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2               17.446427
# 53243585a1d6dc2643021fd1853d8905               31.903976
# 4a3ca9315b744ce9f8e9374361493884               17.648234
# fa1c13f2614d7b5c4749cbc52fecda94               17.137713
# 7c67e1448b00f6e969d365cea6b010ab               37.839113

# %% [markdown]
# - meninjau order dengan transaksi pembelian tertinggi

# %%
order_item_df.groupby(by=['order_id']).price.sum().sort_values(ascending=False).head(5)
# Out:
# order_id
# 03caa2c082116e1d31e67e9ae3700499    13440.0
# 736e1922ae60d0d6a89247b851902527     7160.0
# 0812eb902a67711a1cb742b3cdaa65ae     6735.0
# fefacc66af859508bf1a7934eab1e97f     6729.0
# f5136e38d1a14a4dbd87dff67da82701     6499.0
# Name: price, dtype: float64

# %% [markdown]
# #### Eksplorasi Data order_payments

# %% [markdown]
# - meninjau tipe pembayaran yang paling sering digunakan

# %%
order_payments_df.groupby(by=['payment_type']).agg({
    'order_id': 'nunique',
    'payment_value': ["max", "min", "mean",'sum']
}).sort_values(by=('payment_value', 'sum'),ascending=False)
# Out:
#              order_id payment_value
#               nunique           max    min        mean          sum
# payment_type
# credit_card     76505      13664.08   0.01  163.319021  12542084.19
# boleto          19784       7274.88  11.62  145.034435   2869361.27
# voucher          3869       3184.34   0.00   65.669240    379436.87
# debit_card       1528       4445.50  13.38  142.570170    217989.79

# %% [markdown]
# berdasarkan tabel pivot diatas, dapat di ketahui bahwa pembeli melakukan transaksi pembayaran dinominasi menggunakan credit_card

# %%
order_payments_df.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            4
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# #### Eksplorasi Data order_reviews

# %% [markdown]
# - meninjau jumlah banyaknya review score

# %%
order_reviews_df.groupby(by='review_score').nunique()
# Out:
#               review_id  order_id  review_comment_title  \
# review_score
# 1                 11282     11393                  1218
# 2                  3114      3148                   401
# 3                  8097      8160                   572
# 4                 19007     19098                   747
# 5                 56910     57076                  2173
#
#               review_comment_message  review_creation_date  \
# review_score
# 1                               8426                   569
# 2                               2104                   495
# 3                               3386                   545
# 4                               5355                   570
# 5                              17538                   614
#
#               review_answer_timestamp
# review_score
# 1                               11280
# 2                                3114
# 3                                8097
# 4                               19004
# ...

# %% [markdown]
# - ringkasan statistika orders_reviews

# %%
order_reviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# #### Eksplorasi Data orders_df

# %% [markdown]
# - membuat kolom baru waktu persetujuan pesanan

# %%
time_order_approval = orders_df.order_approved_at - orders_df.order_purchase_timestamp
time_order_approval = time_order_approval.apply(lambda x: x.total_seconds())
orders_df['time_order_approval'] = round(time_order_approval/ 60)

# %%
shipping_preparation_time = orders_df.order_delivered_carrier_date - orders_df.order_approved_at
shipping_preparation_time = shipping_preparation_time.apply(lambda x: x.total_seconds())
orders_df['shipping_preparation_time'] = round(shipping_preparation_time/ 60)

# %%
delivery_time = orders_df.order_delivered_customer_date - orders_df.order_delivered_carrier_date
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df['delivery_time'] = round(delivery_time/ 60)

# %%
orders_df.groupby(by="customer_id").mean()
# Out:
# C:\Users\Candra Burhanudin\AppData\Local\Temp\ipykernel_22516\921667247.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   orders_df.groupby(by="customer_id").mean()
#                                   time_order_approval  \
# customer_id
# 00012a2ce6f8dcda20d059ce98491703                 27.0
# 000161a058600d5901f007fab4c27140                 15.0
# 0001fd6190edaaf884bcaf3d49edf079                  9.0
# 0002414f95344307404f0ace7a26f1d5                841.0
# 000379cdec625522490c315e70c7a9fb               2248.0
# ...                                               ...
# fffecc9f79fd8c764f843e9951b11341                 11.0
# fffeda5b6d849fbd39689bb92087f431                 19.0
# ffff42319e9b2d713724ae527742af25                 23.0
# ffffa3172527f765de70084a7e53aae8                 12.0
# ...

# %%
orders_df[(orders_df['delivery_time']== 0)].groupby(by='order_status').nunique().sort_values(by='order_id', ascending=False)
# Out:
#               order_id  customer_id  order_purchase_timestamp  \
# order_status
# shipped           1098         1098                      1097
# canceled           619          619                       619
# unavailable        609          609                       607
# invoiced           314          314                       314
# processing         301          301                       301
# delivered           15           15                        15
# created              5            5                         5
# approved             2            2                         2
#
#               order_approved_at  order_delivered_carrier_date  \
# order_status
# shipped                    1095                          1095
# canceled                    618                           617
# unavailable                 607                           607
# invoiced                    314                           314
# processing                  301                           301
# ...

# %%
results_orders_df = orders_df.describe().copy()

# %%
results_orders_df['delivery_time'] = round(results_orders_df['delivery_time'] / 1440)
results_orders_df
# Out:
#        time_order_approval  shipping_preparation_time  delivery_time
# count         98059.000000               98059.000000           68.0
# mean            587.524970                4040.481730            9.0
# std            1500.995104                5018.300011            9.0
# min               0.000000                   0.000000            0.0
# 25%              13.000000                1249.000000            4.0
# 50%              20.000000                2603.000000            7.0
# 75%             815.000000                5137.000000           12.0
# max          270551.000000              181098.000000          205.0

# %% [markdown]
# dari hasil diatas didapatkan rata rata proses pengiriman hingga sampai ke pengguna berkisar selama 9 hari

# %% [markdown]
# #### Eksplorasi Data product_category_df

# %%
product_category_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# jumlah data product_category_name berjumlah 71

# %% [markdown]
# #### Eksplorasi Data product_df

# %%
products_df.describe(include='all')
# Out:
#                               product_id product_category_name  \
# count                              32340                 32340
# unique                             32340                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32340.000000                32340.000000             32340.0
# ...

# %%
product = products_df.groupby(by='product_category_name').agg({
    'product_id' : 'nunique',
    'product_weight_g' :'mean',
    'product_length_cm'	:'mean',
    'product_height_cm'	:'mean',
    'product_width_cm':'mean'
}).sort_values(by='product_id',ascending=False).head()
product
# Out:
#                        product_id  product_weight_g  product_length_cm  \
# product_category_name
# cama_mesa_banho              3029       2456.405084          36.774183
# esporte_lazer                2867       2024.670736          31.280084
# moveis_decoracao             2657       3008.266842          43.894994
# beleza_saude                 2444       1434.793781          23.800736
# utilidades_domesticas        2335       3020.793576          31.859957
#
#                        product_height_cm  product_width_cm
# product_category_name
# cama_mesa_banho                14.091119         30.589964
# esporte_lazer                  18.109871         20.824206
# moveis_decoracao               17.438088         28.663154
# beleza_saude                   15.712357         17.997545
# utilidades_domesticas          22.337901         24.821413

# %%
print('jumlah macam barang :',product['product_id'].sum())
# Out:
# jumlah macam barang : 13332

# %% [markdown]
# produk terbanyak diduduki oleh cama_mesa_banho sebanyak 3029 produk

# %% [markdown]
# #### Eksplorasi Data sellers_df

# %% [markdown]
# - meninjau jumlah sellers pada setiap negara bagian

# %%
sellers_df.groupby(by=["seller_state"]).agg({
    "seller_id": "nunique"
}).sort_values(by='seller_id', ascending=False)
# Out:
#               seller_id
# seller_state
# SP                 1849
# PR                  349
# MG                  244
# SC                  190
# RJ                  171
# RS                  129
# GO                   40
# DF                   30
# ES                   23
# BA                   19
# CE                   13
# PE                    9
# PB                    6
# MS                    5
# RN                    5
# MT                    4
# RO                    2
# SE                    2
# AC                    1
# PI                    1
# AM                    1
# MA                    1
# PA                    1

# %% [markdown]
# #### Eksplorasi Data cutomers_df & orders_df

# %% [markdown]
# - menambahkan kolom baru untuk mencari pelanggan aktif atau tidak aktif

# %%
customer_id_in_orders_df = orders_df.customer_id.tolist()
customers_df['status'] = customers_df['customer_id'].apply(lambda x: 'Active' if x in customer_id_in_orders_df else 'Non Active' )

# %% [markdown]
# - meninjau perbandingan pengguna aktif dan non aktif di E-Commerce

# %%
customers_df[customers_df['status']== 'Non Active']
# Out:
#                             customer_id                customer_unique_id  \
# 130    dc53883e94804c81b4afdf2c23478d97  5ece49e012285b9003d084a4ea8a9c94
# 191    2abea2bf3e5611f7a96f8d24f21a7198  ed62ab8aab76f4d4efc4344ba5ef3a6d
# 260    09f548315be5f30a9610b83ad933aaf1  c1c2fffe3d49911803df2e157bee7aa0
# 267    5b7ad66e4a9c19ef5ddceae95d05e46e  b0b18bfffa6a1fb823a25a9167e6877c
# 273    a56b03f5e6015f1a502b9810309b98b7  b6cbe1a8674ee23e9fb086e3c61677b8
# ...                                 ...                               ...
# 99179  b0fdd38d459d6c7fc8118dd3ed73d096  6b8f49efa9b867eb0643ce5cf91aea61
# 99204  e24fceba7ac4b1b1cd1884f05ba68e9d  7410c7ed56c93d4eee17a7b7b3a75b3e
# 99269  269241d3dcdfa33840108eff894f180c  6602e7e0fd01e2fe3e09e73782847478
# 99331  17635f40f800086f9e8990bd43d9aee7  311095a4ee35aef6817083718f97e1c4
# 99368  ec126b0b2593214b75ec14893b15d9e5  78f3a4a5fd7af366fb49942756be9a1d
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %% [markdown]
# dalam hitungan persen

# %%
customers_df.groupby(by='status').customer_id.count() / 99441 * 100
# Out:
# status
# Active        98.610231
# Non Active     1.389769
# Name: customer_id, dtype: float64

# %% [markdown]
# dalam hitungan jumlah data

# %%
customers_df.groupby(by='status').customer_id.count()
# Out:
# status
# Active        98059
# Non Active     1382
# Name: customer_id, dtype: int64

# %% [markdown]
# terdapat cukup banyak pelanggan yang sudah pernah melakukan transaksi

# %% [markdown]
# #### Eksplorasi Data orders_df & ustomers_df

# %%
orders_customers_df = pd.merge(
    left = orders_df[['order_id','customer_id','order_status','order_purchase_timestamp','time_order_approval','shipping_preparation_time','delivery_time']],
    right = customers_df[['customer_id','customer_zip_code_prefix','customer_city','customer_state','status']],
    how = 'left',
    left_on = 'customer_id',
    right_on = 'customer_id'
)
orders_customers_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 98054  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 98055  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 98056  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 98057  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 98058  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp  time_order_approval  \
# ...

# %% [markdown]
# - mengetahui jumlah 5 order teratas berdasarkan negara bagian dengan informasi rata rata lama proses pengiriman (hari)

# %%
orders_customers_df.groupby(by=['customer_state']).agg({
    'order_id':'nunique',
    'delivery_time': lambda x: round(x.mean() /1440)
}).sort_values('order_id',ascending=False).head()
# Out:
#                 order_id  delivery_time
# customer_state
# SP                 41156              5
# RJ                 12712             12
# MG                 11469              9
# RS                  5383             12
# PR                  4964              9

# %% [markdown]
# - mengetahui jumlah 5 order teratas berdasarkan kota bagian dengan informasi rata rata lama proses pengiriman (hari)

# %%
orders_customers_df.groupby(by=['customer_city']).agg({
    'order_id':'nunique',
    'delivery_time': lambda x: round(x.mean() /1440)
}).sort_values('order_id',ascending=False).head()
# Out:
#                 order_id  delivery_time
# customer_city
# sao paulo          15313              5
# rio de janeiro      6801             11
# belo horizonte      2730              8
# brasilia            2092             10
# curitiba            1496              7

# %% [markdown]
# - mengetahui jumlah status order

# %%
orders_customers_df.groupby(by=['order_status']).agg({
    'order_id':'nunique'
}).sort_values('order_id',ascending=False)
# Out:
#               order_id
# order_status
# delivered        95105
# shipped           1098
# canceled           625
# unavailable        609
# invoiced           314
# processing         301
# created              5
# approved             2

# %% [markdown]
# #### Eksplorasi Data order_item_df & order_payments_df

# %%
orders_payment_method_df = pd.merge(
    left = order_item_df[['order_id','order_item_id','product_id','seller_id','price','freight_value']],
    right = order_payments_df[['order_id','payment_type','payment_value']],
    how = 'left',
    left_on = 'order_id',
    right_on = 'order_id'
)
orders_payment_method_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 117599  fffc94f6ce00a00581880bf54a75a037              1
# 117600  fffcd46ef2263f404302a634eb57f7eb              1
# 117601  fffce4705a9662cd70adb13d4a31832d              1
# 117602  fffe18544ffabc95dfada21779c9644f              1
# 117603  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
orders_payment_method_df = orders_payment_method_df.dropna()

# %% [markdown]
# - pivot tabel jumlah transaksi berdasarkan metode pembayaran

# %%
orders_payment_method_df.groupby('payment_type').agg({
    'order_id' : 'nunique',
    'seller_id' : 'nunique',
    'payment_value' : 'sum',

}).sort_values('order_id',ascending=False)
# Out:
#               order_id  seller_id  payment_value
# payment_type
# credit_card      75991       2951    15589028.22
# boleto           19614       2010     4059699.60
# voucher           3766       1046      405873.03
# debit_card        1521        679      253533.86

# %% [markdown]
# #### Eksplorasi Data orders_payment_method_df & order_reviews_df

# %%
orders_result_df = pd.merge(
    left = orders_payment_method_df,
    right = order_reviews_df[['review_id','order_id','review_score','review_comment_title','review_comment_message']],
    how = 'left',
    left_on = 'order_id',
    right_on = 'order_id'
)
orders_result_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118302  fffc94f6ce00a00581880bf54a75a037              1
# 118303  fffcd46ef2263f404302a634eb57f7eb              1
# 118304  fffce4705a9662cd70adb13d4a31832d              1
# 118305  fffe18544ffabc95dfada21779c9644f              1
# 118306  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# - memperbaiki missing values dengan fillna()

# %%
orders_result_df['review_id'] = orders_result_df['review_id'].fillna('none')
orders_result_df['review_score'] = orders_result_df['review_score'].fillna(0)
orders_result_df['review_comment_title'] = orders_result_df['review_comment_title'].fillna('no title')
orders_result_df['review_comment_message'] = orders_result_df['review_comment_message'].fillna('no description')
orders_result_df.isna().sum()
# Out:
# order_id                  0
# order_item_id             0
# product_id                0
# seller_id                 0
# price                     0
# freight_value             0
# payment_type              0
# payment_value             0
# review_id                 0
# review_score              0
# review_comment_title      0
# review_comment_message    0
# dtype: int64

# %% [markdown]
# - pivot tabel sebaran jumlah review product

# %%
review_result = orders_result_df.groupby('review_score').agg({
    'review_id' : 'nunique',
    'payment_value' : 'sum'
}).sort_values('review_id',ascending=False)
review_result.rename(columns={
    'review_id': 'jumlah_review_customer',
    'payment_value': 'jumlah_nilai_transaksi'
})
# Out:
#               jumlah_review_customer  jumlah_nilai_transaksi
# review_score
# 5.0                            56854             10656504.93
# 4.0                            18978              3643544.01
# 1.0                            10765              3456191.28
# 3.0                             8052              1649466.99
# 2.0                             3059               782221.49
# 0.0                                1               228913.84

# %% [markdown]
# #### Eksplorasi Data orders_customers_df & orders_result_df

# %%
orders_temporary_final = pd.merge(
    left = orders_customers_df,
    right = orders_result_df,
    how = 'left',
    left_on = 'order_id',
    right_on = 'order_id'
)
orders_temporary_final
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 117416  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 117417  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 117418  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 117419  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 117420  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp  time_order_approval  \
# ...

# %% [markdown]
# - pivot tabel status order dengan informasi jumlah order, average_shipping_preparation_time (minute), average_delivery_time (day)

# %%
order_status_result = orders_temporary_final.groupby('order_status').agg({
    'order_id' : 'nunique',
    'shipping_preparation_time' : lambda x : round (x.mean() / 60,1),
    'delivery_time' : lambda x : round (x.mean() / 1440,1),
}).sort_values('order_id',ascending=False)
order_status_result.rename(columns={
    'order_id': 'jumlah_order',
    'shipping_preparation_time': 'average_shipping_preparation_time (minute)',
    'delivery_time' : 'average_delivery_time (day)'
})
# Out:
#               jumlah_order  average_shipping_preparation_time (minute)  \
# order_status
# delivered            95105                                        69.6
# shipped               1098                                        80.7
# canceled               625                                         8.5
# unavailable            609                                         0.0
# invoiced               314                                         0.0
# processing             301                                         0.0
# created                  5                                         0.0
# approved                 2                                         0.0
#
#               average_delivery_time (day)
# order_status
# delivered                             9.2
# shipped                               0.0
# canceled                              0.1
# unavailable                           0.0
# invoiced                              0.0
# processing                            0.0
# ...

# %%
orders_temporary_final = orders_temporary_final.dropna()

# %% [markdown]
# #### Eksplorasi Data products_df & orders_result_dfproduct_category_df

# %%
products_df_merge = pd.merge(
    left = products_df[['product_id','product_category_name','product_weight_g']],
    right = product_category_df,
    how = 'left',
    left_on = 'product_category_name',
    right_on = 'product_category_name'
)

# %%
products_df_merge = products_df_merge.drop('product_category_name', axis=1)
products_df_merge
# Out:
#                              product_id  product_weight_g  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5             225.0
# 1      3aa071139cb16b67ca9e5dea641aaa2f            1000.0
# 2      96bd76ec8810374ed1b65e291975717f             154.0
# 3      cef67bcfe19066a932b7673e239eb23d             371.0
# 4      9dc1a7de274444849c219cff195d0b71             625.0
# ...                                 ...               ...
# 32335  a0b7d5a992ccda646f2d34e418fff5a0           12300.0
# 32336  bf4538d88321d0fd4412a93c974510e6            1700.0
# 32337  9a7c6041fa9592d9d9ef6cfe62a71f8c            1400.0
# 32338  83808703fc0706a22e264b9d75f04a2e             700.0
# 32339  106392145fca363410d287a815be6de4            2083.0
#
#       product_category_name_english
# 0                         perfumery
# 1                               art
# 2                    sports_leisure
# 3                              baby
# 4                        housewares
# ...                             ...
# ...

# %%
products_df_merge = products_df_merge.dropna()
products_df_merge.isna().sum()
# Out:
# product_id                       0
# product_weight_g                 0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# - pivot rata rata berat jenis produk kategori

# %%
average_product_category_weight = products_df_merge.groupby('product_category_name_english').agg({
    'product_weight_g' : 'mean'
}).sort_values('product_weight_g',ascending=False).head()
average_product_category_weight.rename(columns={
    'product_weight_g': 'average_product_weight_g'
})
# Out:
#                                          average_product_weight_g
# product_category_name_english
# furniture_mattress_and_upholstery                    13190.000000
# office_furniture                                     12740.867314
# kitchen_dining_laundry_garden_furniture              11598.563830
# furniture_bedroom                                     9997.222222
# home_appliances_2                                     9913.333333

# %% [markdown]
# #### Eksplorasi Data orders_temporary_final & products_df_merge

# %%
merge_order_temporary_product_df = pd.merge(
    left = orders_temporary_final,
    right = products_df_merge,
    how = 'left',
    left_on = 'product_id',
    right_on = 'product_id'
)

# %%
merge_order_temporary_product_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# time_order_approval                 0
# shipping_preparation_time           0
# delivery_time                       0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# status                              0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# price                               0
# freight_value                       0
# payment_type                        0
# payment_value                       0
# review_id                           0
# review_score                        0
# review_comment_title                0
# review_comment_message              0
# product_weight_g                 1724
# product_category_name_english    1724
# dtype: int64

# %%
merge_order_temporary_product_df['product_weight_g'].fillna(merge_order_temporary_product_df['product_weight_g'].mean(), inplace=True)
merge_order_temporary_product_df['product_category_name_english'].fillna('unknown', inplace=True)

# %%
merge_order_temporary_product_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# time_order_approval              0
# shipping_preparation_time        0
# delivery_time                    0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# status                           0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# price                            0
# freight_value                    0
# payment_type                     0
# payment_value                    0
# review_id                        0
# review_score                     0
# review_comment_title             0
# review_comment_message           0
# product_weight_g                 0
# product_category_name_english    0
# dtype: int64

# %%
sales_order_result = merge_order_temporary_product_df.groupby(['customer_state','product_category_name_english']).agg({
    'order_id' : 'nunique',
    'product_id' : 'count',
    'review_score' : lambda x : round (x.mean()),
    'payment_value' : 'sum'
}).sort_values(['order_id', 'product_id', 'payment_value'],ascending=False)
sales_order_result = sales_order_result.rename(columns={
    'order_id': 'jumlah_order',
    'product_id': 'jumlah produk',
    'review_score' : 'average_review_score',
    'payment_value' : 'total_payment_value'
})
sales_order_result.head(20)
# Out:
#                                               jumlah_order  jumlah produk  \
# customer_state product_category_name_english
# SP             bed_bath_table                         4346           5571
#                health_beauty                          3731           4279
#                sports_leisure                         3263           3794
#                housewares                             2730           3415
#                furniture_decor                        2689           3744
#                computers_accessories                  2645           3229
#                watches_gifts                          2101           2318
#                auto                                   1586           1776
#                toys                                   1584           1744
#                telephony                              1502           1692
# RJ             bed_bath_table                         1379           1783
# ...

# %% [markdown]
# #### Eksplorasi Data merge_order_temporary_product_df & sellers_df

# %%
all_df = pd.merge(
    left = merge_order_temporary_product_df,
    right= sellers_df,
    how = 'left',
    left_on = 'seller_id',
    right_on= 'seller_id'
)

# %%
all_df.order_id.nunique()
# Out:
# 97283

# %%
all_df.groupby(by=['seller_state', 'product_category_name_english']).agg({
    'order_id' : 'nunique',
    'payment_value' : 'sum'
}).sort_values(by=['payment_value','order_id'],ascending=False)
# Out:
#                                             order_id  payment_value
# seller_state product_category_name_english
# SP           bed_bath_table                     8214     1508245.88
#              watches_gifts                      4503     1093841.29
#              furniture_decor                    4637     1052949.84
#              health_beauty                      5732      946768.81
#              sports_leisure                     4846      839589.54
# ...                                              ...            ...
# ES           electronics                           1          44.28
# MG           cine_photo                            1          42.72
#              arts_and_craftmanship                 1          33.69
# ES           telephony                             1          32.10
# PR           food_drink                            1          22.52
#
# [511 rows x 2 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Tujuan
# menjawab seluruh pertanyaan analisis atau bisnis yang sebelumnya telah dibuat; dan
# membuat visualisasi data untuk mempermudah penyampaian hasil analisis data.
#
# Alur Latihan
# * Persiapan.
# * Membuat visualisasi data yang menjawab pertanyaan bisnis.
# * Export all_df ke csv

# %% [markdown]
# ### Pertanyaan 1: Bagaimana performa penjualan dan transaction E-Commerce dalam beberapa bulan terakhir?

# %%
monthly_orders_df = all_df[all_df['order_status'] == 'delivered'].resample(rule='M', on='order_purchase_timestamp').agg({
        'order_id' : 'nunique',
        'payment_value' : 'sum'
  })
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    'order_id' : 'order_count',
    'payment_value' : 'transaction'
}, inplace=True)
monthly_orders_df
# Out:
#    order_purchase_timestamp  order_count  transaction
# 0                   2016-10          261     61277.26
# 1                   2016-11            0         0.00
# 2                   2016-12            1        19.62
# 3                   2017-01          749    177868.80
# 4                   2017-02         1650    326888.98
# 5                   2017-03         2545    508539.30
# 6                   2017-04         2279    453416.74
# 7                   2017-05         3531    705015.17
# 8                   2017-06         3130    589319.27
# 9                   2017-07         3841    712622.50
# 10                  2017-08         4190    847587.05
# 11                  2017-09         4137    998776.67
# 12                  2017-10         4478   1012420.44
# 13                  2017-11         7288   1559468.33
# 14                  2017-12         5508   1022772.42
# 15                  2018-01         7045   1378701.02
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(
    monthly_orders_df['order_purchase_timestamp'],
    monthly_orders_df['order_count'], 
    marker='o', 
    linewidth=2, 
    color='#72BCD4')
plt.title("Number of Orders per Month", loc="center", fontsize=20)
plt.xticks(rotation=45)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df['order_purchase_timestamp'],
    monthly_orders_df['transaction'],
    marker='o',
    linewidth=2,
    color='#72BCD4'
)
plt.title("Total Transactions per Month", loc="center", fontsize=20)
plt.xticks(rotation=45)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
monthly_orders_df.describe()
# Out:
#        order_count   transaction
# count    23.000000  2.300000e+01
# mean   4134.956522  8.527805e+05
# std    2434.711304  5.078769e+05
# min       0.000000  0.000000e+00
# 25%    2412.000000  4.809780e+05
# 50%    4190.000000  9.987767e+05
# 75%    6337.000000  1.278594e+06
# max    7288.000000  1.559468e+06

# %% [markdown]
# ### Pertanyaan 2: kategori Produk apa yang paling banyak dan paling sedikit terjual?

# %%
sum_order_items_df = all_df[all_df['order_status'] == 'delivered'].groupby('product_category_name_english').product_id.count().sort_values(ascending=False).reset_index()
sum_order_items_df = sum_order_items_df.rename(columns={
   'product_id' : 'quantity'
})

# %%
fig, ax = plt.subplots(nrows = 1, ncols=2, figsize=(34,18))
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x='quantity',y='product_category_name_english', data=sum_order_items_df.head(5),palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title('Best Performing Product', loc='center', fontsize=22)
ax[0].tick_params(axis='y', labelsize =24)
ax[0].tick_params(axis='x', labelsize=24)

sns.barplot(x='quantity',y='product_category_name_english', data=sum_order_items_df.sort_values(by='quantity',ascending=True).head(5),palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.tick_right()
ax[1].set_title('Worst Performing Product', loc='center', fontsize=22)
ax[1].tick_params(axis='y', labelsize =24)
ax[1].tick_params(axis='x', labelsize=24)

plt.suptitle('Best and Worst Performing Product by Number of Sales', fontsize=24)
plt.show()

# %% [markdown]
# ### Pertanyaan 3: Bagaimana sebaran pelanggan yang kita miliki menurut negara & kota?

# %%
order_bystate_df = all_df.groupby(by='customer_state').customer_id.nunique().reset_index()
order_bystate_df.rename(columns = {
    'customer_id' : 'customer_count'
},inplace=True)

plt.figure(figsize=(10, 5))

sns.barplot(
    x='customer_count',
    y= 'customer_state',
    data = order_bystate_df.sort_values(by='customer_count',ascending=False).head(),
    palette= colors
)

plt.title('highest distribution of customers by state', loc='center', fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x',labelsize=12)
plt.show()

# %%
order_bycity_df = all_df.groupby(by='customer_city').customer_id.nunique().reset_index()
order_bycity_df.rename(columns = {
     'customer_id' : 'customer_count'
},inplace=True)

plt.figure(figsize=(10, 5))

sns.barplot(
    x='customer_count',
    y= 'customer_city',
    data = order_bycity_df.sort_values(by='customer_count',ascending=False).head(),
    palette= colors
)

plt.title('highest distribution of customers by city', loc='center', fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x',labelsize=12)
plt.show()

# %% [markdown]
# ### Pertanyaan 4: Bagaimana Metode Pembayaran Pelanggan Yang sering digunakan?

# %%
customers_payments_method_df = all_df.groupby('payment_type').order_id.nunique().reset_index()
customers_payments_method_df.rename(columns = {
    'order_id' : 'order_count'
},inplace=True)
plt.figure(figsize=(10, 5))
sns.barplot(
    x= 'payment_type',
    y= 'order_count',
    data = customers_payments_method_df.sort_values(by='order_count',ascending=False),
    palette= colors
)
plt.title('customers payment method', loc='center', fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x',labelsize=12)
plt.show()

# %% [markdown]
# ### Pertanyaan 5: berapa tingkat order & transaksi pelanggan yang di batalkan berdasarkan bulan terakhir?

# %%
monthly_canceled_orders_df = all_df[all_df['order_status'] == 'canceled'].resample(rule='M', on='order_purchase_timestamp').agg({
        'order_id' : 'nunique',
        'payment_value' : 'sum'
  })
monthly_canceled_orders_df.index = monthly_canceled_orders_df.index.strftime('%Y-%m')
monthly_canceled_orders_df = monthly_canceled_orders_df.reset_index()
monthly_canceled_orders_df.rename(columns={
    'order_id' : 'order_count',
    'payment_value' : 'transaction'
}, inplace=True)
monthly_canceled_orders_df
# Out:
#    order_purchase_timestamp  order_count  transaction
# 0                   2016-09            1        75.06
# 1                   2016-10           12      3913.19
# 2                   2016-11            0         0.00
# 3                   2016-12            0         0.00
# 4                   2017-01            2       245.03
# 5                   2017-02           15      2718.93
# 6                   2017-03           24      6500.71
# 7                   2017-04           14     16979.91
# 8                   2017-05           20      6943.02
# 9                   2017-06           12      3310.80
# 10                  2017-07           23      7417.77
# 11                  2017-08           21      7030.04
# 12                  2017-09           16      3321.31
# 13                  2017-10           21      4889.96
# 14                  2017-11           30     12142.29
# 15                  2017-12            6      2537.47
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(
    monthly_canceled_orders_df['order_purchase_timestamp'],
    monthly_canceled_orders_df['order_count'], 
    marker='o', 
    linewidth=2, 
    color='#72BCD4')
plt.title("Number of Canceled Orders per Month", loc="center", fontsize=20)
plt.xticks(rotation=45)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(
    monthly_canceled_orders_df['order_purchase_timestamp'],
    monthly_canceled_orders_df['transaction'], 
    marker='o', 
    linewidth=2, 
    color='#72BCD4')
plt.title("Number of Canceled Transactions per Month", loc="center", fontsize=20)
plt.xticks(rotation=45)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Pertanyaan 6 : Kapan terakhir pelanggan melakukan transaksi?

# %%
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max", 
    "order_id": "nunique",
    "payment_value": "sum" 
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1    114.74      337
# 1  000161a058600d5901f007fab4c27140          1     67.41      458
# 2  0001fd6190edaaf884bcaf3d49edf079          1    195.42      596
# 3  0002414f95344307404f0ace7a26f1d5          1    179.35      427
# 4  000379cdec625522490c315e70c7a9fb          1    107.01      198

# %%
print('average recency :',round(rfm_df['recency'].mean(),1))
print('min recency :',round(rfm_df['recency'].min(),1))

print('average monetary :',round(rfm_df['monetary'].mean(),2))
print('max monetary :',round(rfm_df['monetary'].max(),2))

print('average frequency :',round(rfm_df['frequency'].mean(),1))
print('max frequency :',round(rfm_df['frequency'].max(),1))
# Out:
# average recency : 291.6
# min recency : 44
# average monetary : 207.1
# max monetary : 109312.64
# average frequency : 1.0
# max frequency : 1

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]
sns.barplot(x="recency", y="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax)
ax.set_ylabel(None)
ax.set_xlabel(None)
ax.set_title("By Recency (days)", loc="center", fontsize=16)
ax.tick_params(axis ='y', labelsize=16)

# %% [markdown]
# ### Pertanyaan 7 : Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]
sns.barplot(x="frequency", y="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax)
ax.set_ylabel(None)
ax.set_xlabel(None)
ax.set_title("By Frequency", loc="center", fontsize=16)
ax.tick_params(axis='y', labelsize=16)

# %% [markdown]
# ### Pertanyaan 7 : Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]
sns.barplot(x="monetary", y="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax)
ax.set_ylabel(None)
ax.set_xlabel(None)
ax.set_title("By Monetary", loc="center", fontsize=18)
ax.tick_params(axis='y', labelsize=16)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Conclution Pertanyaan 1 : Bagaimana performa penjualan dan transaction E-Commerce dalam beberapa bulan terakhir?
# Sepanjang bulan berlangsung performa penjualan jumlah order tertinggi terjadi pada 2017-11 dengan order sebanyak 7888 dengan transaksi hingga 1559468.33 dan performa penjualan terendah terjadi pada 2016-11 dengan order sebanyak 0 dengan jumlah transaksai bernilai 0

# %% [markdown]
# ### Conclution Pertanyaan 2 : kategori Produk apa yang paling banyak dan paling sedikit terjual?
# hasil diagram batang menunjukan bahwa product security_and_services accessories menduduki produk yang paling sedikit penjualan dengan jumlah 2 saja. untuk produk yang menduduki peringkat teratas penjualan diraih oleh kategori produk bed_bath_table dengan jumlah 11635 barang terjual

# %% [markdown]
# ### Conclution Pertanyaan 3 : Bagaimana sebaran pelanggan yang kita miliki menurut negara & kota?
# hasil diagram batang menunjukan potensi pasar terbesar di peroleh negara bagian dengan kode SP dengan jumlah customer aktif sebanyak 40784 dan peringkat kedua diduduki oleh negara bagian dengan kode RJ dengan jumlah customer aktif sebanyak 12622
#
# jika diurutkan berdasarkan kota, potensi pasar pelanggan terbesar diraih oleh kota sao paulo dengan jumlah customer 15175 dan diikuti oleh peringkat kedua diraih oleh kota rio de janeiro dengan jumlah pelanggan 6753

# %% [markdown]
# ### Conclution Pertanyaan 4 : Bagaimana Metode Pembayaran Pelanggan Yang sering digunakan?
# peringkat awal metode pembayaran yang menjadi favorit pelanggan adalah credit_card dengan jumlah order dengan metode pembayaran credit card mencapai 74962 order diikuti olehperingkat kedua yaitu boleto dengan jumlah order 19322

# %% [markdown]
# ### Conclution Pertanyaan 5 : berapa tingkat transaksi & jumlah order pelanggan yang di batalkan berdasarkan bulan terakhir?
# berdasarkan hasil diagram garis jumlah order yang dibatalkan selama sepanjang bulan bernilai total 461 jumlah order dengan jumlah transaksi yang dibatalkan sebesar BRL 150616.439. tingkat proses pembatalan order terjadi meningkat derastis mulai dari 2017-11 hingga 2018-01

# %% [markdown]
# ### Conclution Pertanyaan 6 : Kapan terakhir pelanggan melakukan transaksi?
# berdasarkan hasil kalkulasi recency didapatkan rata rata pelanggan melakukan transaksi di platform berlangsung pada 291 hari yang lalu. nilai terdekat yaitu pelanggan melakukan transaksi pada 44 hari yang lalu dari data sepanjang bulan

# %% [markdown]
# ### Conclution Pertanyaan 7 : Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# berdasarkan hasil kalkulasi frequency didapatkan rata rata pelanggan melakukan pembelian dengan frekuensi 1x order saja

# %% [markdown]
# ### Conclution Pertanyaan 8 : Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?
# berdasarkan hasil kalkulasi monetary didapatkan rata rata pelanggan menghabiskan uang untuk berbelanja sebesar BRL 207,1, nilai maksimum tercapai dalam transaksi order mencapai BRL 109312
